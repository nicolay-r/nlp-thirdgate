# %% [markdown]
# <a href="https://colab.research.google.com/github/nicolay-r/nlp-thirdgate/blob/master/tutorials/llm_deep_seek_7b_distill_qwen2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/nicolay-r/nlp-thirdgate/refs/heads/master/llm/transformers_qwen2.py
# Out:
# --2025-02-23 11:00:36--  https://raw.githubusercontent.com/nicolay-r/nlp-thirdgate/refs/heads/master/llm/transformers_qwen2.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1419 (1.4K) [text/plain]
# Saving to: ‘transformers_qwen2.py’
#
# transformers_qwen2. 100%[===================>]   1.39K  --.-KB/s    in 0s
#
# 2025-02-23 11:00:36 (16.5 MB/s) - ‘transformers_qwen2.py’ saved [1419/1419]

# %%
# !pip install bulk-chain
# Out:
# Collecting bulk-chain
#   Downloading bulk_chain-0.25.0-py3-none-any.whl.metadata (3.9 kB)
# Downloading bulk_chain-0.25.0-py3-none-any.whl (14 kB)
# Installing collected packages: bulk-chain
# Successfully installed bulk-chain-0.25.0

# %%
from bulk_chain.core.utils import dynamic_init
from bulk_chain.api import iter_content

llm = dynamic_init(class_dir=".",
                   class_filepath="transformers_qwen2.py",
                   class_name="Qwen2")(model_name="deepseek-ai/DeepSeek-R1-Distill-Qwen-7B",
                                       api_token="<YOUR-HF-API-TOKEN-GOES-THERE>",
                                       use_bf16=False,
                                       temp=0.6)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/680 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/28.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-000002.safetensors:   0%|          | 0.00/8.61G [00:00<?, ?B/s]
# model-00002-of-000002.safetensors:   0%|          | 0.00/6.62G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/3.07k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]

# %%
data_it = [
    {"text": "what's the color of the sky?"},
    {"text": "what's the color of the ground?"}
]

schema = {
  "schema": [
    {"prompt": "{text}", "out": "response"}
  ]
}

content_it = iter_content(data_it, llm=llm, schema=schema,
                          return_batch=False, batch_size=1)

for content in content_it:
    print(content["response"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:151643 for open-end generation.
# Okay, so the question is asking about the color of the sky. Hmm, I know that the sky appears blue most of the time, but I've heard that sometimes it's different. Let me think about why the sky is blue. I remember learning in school that it's because of something called Rayleigh scattering. So, when sunlight hits the Earth's atmosphere, the light scatters in different directions. Blue light scatters more than other colors because it has a shorter wavelength. That's why the sky looks blue during the day.
#
# But wait, what about during sunrise or sunset? I've noticed the sky turns different colors, like red or orange. I think that's because of Rayleigh scattering as well, but during these times, the sun is closer to the horizon. The light has to travel through more of the Earth's atmosphere, right? And when light scatters off particles in the air, the longer wavelengths, like red and orange, are scattered more in these directions. So, during sunrise and sunset, the sky looks red or orange because those colors are scattered towards our line of sight.
#
# Then there's the possibility of other colors. I've heard that on some days, especially cloudy ones, the sky might look gray or even yellow. Gray makes sense because when there's a lot of cloud cover, the direct sunlight is blocked, and the scattered light is less, so it looks darker. Yellow might happen when there are particles in the air, like dust or pollution, which can scatter the blue light less, making the sky appear yellow instead of blue.
#
# I also wonder about the moonlight. I think the moon reflects sunlight, so it's white. But when it's a new moon, the moon doesn't reflect much sunlight, so it looks dark. During the full moon, it reflects all the sunlight, so it's white. But the question was about the sky, not the moon, so that's probably not relevant here.
#
# Another thought: sometimes the sky can look different depending on the time of year or atmospheric conditions. For example, during stormy weather, the sky might look gray or even black because of the water droplets in clouds scattering light differently. Or during hazy days, the sky might appear more gray or brown because of the particles in the air scattering the light.
#
# I should also consider other factors, like pollution or pollution particles. If there's a lot of pollution, the sky might look more yellow or orange because the
